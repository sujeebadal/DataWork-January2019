# %%
import pandas as pd
import numpy as np

# %%
location = "datasets/DC_Properties.csv"
df = pd.read_csv(location)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0   ...    -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0   ...    -77.040764       Old City 2   040 D Old City 2
# 2  1910.0   2009.0   ...    -77.040678       Old City 2   040 D Old City 2
# 3  1900.0   2003.0   ...    -77.040629       Old City 2   040 D Old City 2
# 4  1913.0   2012.0   ...    -77.039361       Old City 2   040 D Old City 2
#
# ...

# %%
df.count()
# Out:
# Unnamed: 0            158957
# BATHRM                158957
# HF_BATHRM             158957
# HEAT                  158957
# AC                    158957
# NUM_UNITS             106696
# ROOMS                 158957
# BEDRM                 158957
# AYB                   158686
# YR_RMDL                80928
# EYB                   158957
# STORIES               106652
# SALEDATE              132187
# PRICE                  98216
# QUALIFIED             158957
# SALE_NUM              158957
# GBA                   106696
# BLDG_NUM              158957
# STYLE                 106696
# STRUCT                106696
# GRADE                 106696
# CNDTN                 106696
# EXTWALL               106696
# ROOF                  106696
# INTWALL               106696
# KITCHENS              106695
# FIREPLACES            158957
# USECODE               158957
# LANDAREA              158957
# GIS_LAST_MOD_DTTM     158957
# SOURCE                158957
# CMPLX_NUM              52261
# ...

# %%
df_missing=pd.read_csv (location)
df_missing.head ()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0   ...    -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0   ...    -77.040764       Old City 2   040 D Old City 2
# ...

# %%
df_missing.isnull().sum ()
# Out:
# Unnamed: 0                 0
# BATHRM                     0
# HF_BATHRM                  0
# HEAT                       0
# AC                         0
# NUM_UNITS              52261
# ROOMS                      0
# BEDRM                      0
# AYB                      271
# YR_RMDL                78029
# EYB                        0
# STORIES                52305
# SALEDATE               26770
# PRICE                  60741
# QUALIFIED                  0
# SALE_NUM                   0
# GBA                    52261
# BLDG_NUM                   0
# STYLE                  52261
# STRUCT                 52261
# GRADE                  52261
# CNDTN                  52261
# EXTWALL                52261
# ROOF                   52261
# INTWALL                52261
# KITCHENS               52262
# FIREPLACES                 0
# USECODE                    0
# LANDAREA                   0
# GIS_LAST_MOD_DTTM          0
# SOURCE                     0
# CMPLX_NUM             106696
# ...

# %%
missing= df_missing ['ASSESSMENT_SUBNBHD'].isnull()
df_missing.loc [missing]
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 92              92       2          0  Hot Water Rad  N        1.0      7
# 93              93       2          3  Hot Water Rad  N        1.0     12
# 257            257       1          1     Forced Air  Y        1.0      4
# 258            258       1          1     Forced Air  Y        1.0      4
# 259            259       2          0     Forced Air  Y        2.0      6
# 260            260       2          0  Hot Water Rad  N        2.0      6
# 261            261       1          0     Forced Air  Y        1.0      6
# 262            262       3          0      Warm Cool  Y        3.0      9
# 263            263       2          1     Forced Air  Y        1.0      5
# 264            264       1          0  Hot Water Rad  N        1.0      6
# 265            265       1          1      Warm Cool  Y        1.0      5
# 266            266       1          0  Hot Water Rad  N        1.0      4
# ...

# %%
#descriptive statistics
df.describe ()
# Out:
#           Unnamed: 0         BATHRM      HF_BATHRM      NUM_UNITS  \
# count  158957.000000  158957.000000  158957.000000  106696.000000
# mean    79478.000000       1.810678       0.458237       1.198039
# std     45887.077707       0.976396       0.587571       0.596924
# min         0.000000       0.000000       0.000000       0.000000
# 25%     39739.000000       1.000000       0.000000       1.000000
# 50%     79478.000000       2.000000       0.000000       1.000000
# 75%    119217.000000       2.000000       1.000000       1.000000
# max    158956.000000      14.000000      11.000000       6.000000
#
#                ROOMS          BEDRM            AYB       YR_RMDL  \
# count  158957.000000  158957.000000  158686.000000  80928.000000
# mean        6.187736       2.732506    1941.987579   1998.243537
# std         2.618165       1.358864      33.640234     16.575786
# min         0.000000       0.000000    1754.000000     20.000000
# ...

# %%
df['PRICE'].mean()
# Out:
# 931351.5949336156

# %%
df['PRICE'].max()
# Out:
# 137427545.0

# %%
df['PRICE'].min()
# Out:
# 1.0

# %%
df.groupby(['AYB', 'SALEDATE', 'PRICE']).mean()
# Out:
#                                       Unnamed: 0  BATHRM  HF_BATHRM  \
# AYB    SALEDATE            PRICE
# 1754.0 2016-08-23 00:00:00 7100000.0     37034.0     7.0        2.0
# 1765.0 2016-08-02 00:00:00 1100000.0     19576.0     2.0        1.0
# 1776.0 1998-07-22 00:00:00 223500.0       5128.0     3.0        0.0
#        2009-04-17 00:00:00 725000.0       5130.0     2.0        1.0
# 1780.0 2016-04-04 00:00:00 825000.0      21630.0     1.0        1.0
#        2016-09-22 00:00:00 660000.0     112869.0     2.0        1.0
#        2016-10-25 00:00:00 830000.0     112870.0     2.0        1.0
# 1790.0 1996-01-19 00:00:00 812500.0      18326.0     2.0        0.0
#        2015-06-29 00:00:00 2549000.0     20766.0     3.0        1.0
#        2017-08-24 00:00:00 1175000.0     19614.0     2.0        0.0
# 1794.0 2013-08-13 00:00:00 1550000.0     19606.0     3.0        0.0
#        2017-05-24 00:00:00 5250000.0     19304.0     5.0        1.0
# ...

# %%
df['PRICE'].groupby(df['ZIPCODE']).mean()
# Out:
# ZIPCODE
# 20001.0    5.215550e+05
# 20002.0    4.628894e+05
# 20003.0    5.992484e+05
# 20004.0    4.755701e+05
# 20005.0    2.813137e+06
# 20006.0    1.959069e+05
# 20007.0    9.794061e+05
# 20008.0    8.522766e+05
# 20009.0    6.215259e+05
# 20010.0    5.070154e+05
# 20011.0    4.259763e+05
# 20012.0    4.755227e+05
# 20015.0    7.703746e+05
# 20016.0    5.914537e+06
# 20017.0    4.087405e+05
# 20018.0    3.691101e+05
# 20019.0    2.302621e+05
# 20020.0    2.281464e+05
# 20024.0    3.808846e+05
# 20032.0    3.235769e+05
# 20036.0    4.015452e+05
# 20037.0    6.124601e+05
# 20052.0    5.378571e+05
# 20392.0    3.489169e+05
# Name: PRICE, dtype: float64

# %%
df['PRICE'].groupby(df['YR_RMDL']).mean()
# Out:
# YR_RMDL
# 20.0      3.350000e+05
# 1880.0    5.700000e+05
# 1900.0    4.150000e+05
# 1910.0    3.300000e+05
# 1911.0             NaN
# 1912.0             NaN
# 1913.0             NaN
# 1915.0             NaN
# 1916.0             NaN
# 1917.0    2.860000e+05
# 1920.0    2.025000e+05
# 1921.0    2.990000e+05
# 1922.0    4.500000e+05
# 1923.0    9.000000e+04
# 1924.0             NaN
# 1925.0    2.165000e+05
# 1926.0    7.537500e+05
# 1927.0    4.150083e+05
# 1928.0    3.999500e+05
# 1929.0    3.439275e+05
# 1930.0    9.500000e+05
# 1931.0    2.030050e+05
# 1932.0    1.000000e+06
# 1933.0             NaN
# 1934.0    1.595000e+06
# 1935.0    5.862500e+05
# 1936.0    4.700000e+05
# 1937.0             NaN
# 1938.0             NaN
# 1939.0    2.657500e+05
#               ...
# 1990.0    6.295934e+05
# 1991.0    4.198709e+05
# 1992.0    5.477510e+05
# 1993.0    4.489786e+05
# 1994.0    5.888261e+05
# 1995.0    6.939913e+05
# 1996.0    5.459179e+05
# 1997.0    6.738446e+05
# ...

# %%
#multiple conditions
df.loc[(df['YR_RMDL'] >= 2007) & (df['YR_RMDL'] < 2017) & (df['PRICE'] >= 400000) & (df['PRICE'] < 800000)] #between year 2007 and 2017
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 19              19       3          1  Hot Water Rad  Y        2.0      9
# 45              45       3          1     Forced Air  Y        2.0     10
# 55              55       3          1     Forced Air  Y        2.0      8
# 69              69       3          1  Hot Water Rad  N        3.0     10
# 73              73       2          1      Warm Cool  Y        1.0      7
# 97              97       4          0      Warm Cool  Y        4.0     12
# 101            101       4          1      Warm Cool  Y        2.0     11
# 133            133       3          1      Warm Cool  Y        1.0      9
# 148            148       2          1      Warm Cool  Y        1.0      5
# 161            161       1          1      Warm Cool  Y        1.0      6
# 163            163       1          1      Warm Cool  Y        1.0      6
# 205            205       3          0      Warm Cool  Y        2.0      9
# ...

# %%
df.fillna(0)
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 1                1       3          1      Warm Cool  Y        2.0     11
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 4                4       2          1      Warm Cool  Y        1.0     11
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 6                6       1          0      Warm Cool  Y        2.0      5
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 9                9       1          1  Hot Water Rad  Y        1.0      6
# 10              10       3          0     Forced Air  N        3.0     12
# 11              11       5          0  Hot Water Rad  Y        3.0     16
# ...

# %%
dupe = df.duplicated() #creates list of True/False values
df[dupe] #shows rows where duplicated is True
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
df2= df [['YR_RMDL','FULLADDRESS','SALEDATE','PRICE']]
df2
# Out:
#         YR_RMDL                   FULLADDRESS             SALEDATE      PRICE
# 0        1988.0          1748 SWANN STREET NW  2003-11-25 00:00:00  1095000.0
# 1        2007.0          1746 SWANN STREET NW  2000-08-17 00:00:00        NaN
# 2        2009.0          1744 SWANN STREET NW  2016-06-21 00:00:00  2100000.0
# 3        2003.0          1742 SWANN STREET NW  2006-07-12 00:00:00  1602000.0
# 4        2012.0  1804 NEW HAMPSHIRE AVENUE NW                  NaN        NaN
# 5           NaN              1709 S STREET NW  2010-02-26 00:00:00  1950000.0
# 6        1988.0          1769 SWANN STREET NW  2011-05-02 00:00:00        NaN
# 7        2011.0          1746 1/2 T STREET NW  2011-09-29 00:00:00  1050000.0
# 8        2008.0          1727 SWANN STREET NW  2018-05-03 00:00:00  1430000.0
# 9        1979.0          1733 SWANN STREET NW  2008-12-05 00:00:00        NaN
# 10       1950.0          1755 SWANN STREET NW                  NaN        NaN
# ...

# %%
df3=df2.loc[(df2['PRICE'] >= 5000000)] 
df3
# Out:
#         YR_RMDL                   FULLADDRESS             SALEDATE       PRICE
# 2149     2005.0  1714 MASSACHUSETTS AVENUE NW  2009-11-30 00:00:00  11984000.0
# 2556     2005.0              1824 R STREET NW  2014-02-14 00:00:00   8450000.0
# 3303        NaN                10 N STREET SW  2015-08-24 00:00:00  11000000.0
# 18177    2007.0      2613 DUMBARTON STREET NW  2018-06-27 00:00:00   5000000.0
# 18350    2014.0              3249 N STREET NW  2013-01-25 00:00:00   7550000.0
# 18585    2009.0              3024 Q STREET NW  2017-05-11 00:00:00   6750000.0
# 18853    2001.0           1315 31ST STREET NW  2010-04-15 00:00:00   5450000.0
# 18869    2002.0              3323 P STREET NW  2016-02-05 00:00:00   5700000.0
# 18870    2008.0              3327 P STREET NW  2011-04-25 00:00:00   6750000.0
# 18871       NaN              3327 P STREET NW  2011-04-25 00:00:00   6750000.0
# 19019    2000.0              3053 P STREET NW  2018-01-17 00:00:00   7365000.0
# ...

# %%
df3.fillna(0)
# Out:
#         YR_RMDL                   FULLADDRESS             SALEDATE       PRICE
# 2149     2005.0  1714 MASSACHUSETTS AVENUE NW  2009-11-30 00:00:00  11984000.0
# 2556     2005.0              1824 R STREET NW  2014-02-14 00:00:00   8450000.0
# 3303        0.0                10 N STREET SW  2015-08-24 00:00:00  11000000.0
# 18177    2007.0      2613 DUMBARTON STREET NW  2018-06-27 00:00:00   5000000.0
# 18350    2014.0              3249 N STREET NW  2013-01-25 00:00:00   7550000.0
# 18585    2009.0              3024 Q STREET NW  2017-05-11 00:00:00   6750000.0
# 18853    2001.0           1315 31ST STREET NW  2010-04-15 00:00:00   5450000.0
# 18869    2002.0              3323 P STREET NW  2016-02-05 00:00:00   5700000.0
# 18870    2008.0              3327 P STREET NW  2011-04-25 00:00:00   6750000.0
# 18871       0.0              3327 P STREET NW  2011-04-25 00:00:00   6750000.0
# 19019    2000.0              3053 P STREET NW  2018-01-17 00:00:00   7365000.0
# ...

# %%
#The data had 158957 rows and 49 columns. There were no duplicates in the data. 
#I ran analysis to find mean for the Price which was $931351.6 and the highest price for house was $137427545.0.  
#I applied multiple conditions to generate data with year remodeled between year 2007 and 2017; and price between $400000 and $80000 to make the data smaller, which generated a new table with 8858 rows × 49 columns.
#I used groupby to group price by year remodelled and price by zipcode.I generated table with fewer variables (year remodelled, full address, saledate and price). I generated table which had prices of houses more than $5000000, and also filled in the null values with 0.
